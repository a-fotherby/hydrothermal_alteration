# %%
# %load_ext autoreload
# %autoreload 2
import cmcrameri.cm as cm  # Importing the cmcrameri colormaps
# %run '../pf_data.py' '~/work/hydrothermal_alteration/pflotran_model/little_dev_model/flow_steady_state/steady_flow.h5'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/work/hydrothermal_alteration/paper_figures/pf_data.py:131
#     128     data = pfl.h5_to_xarray(hdf)
#     130 primary_minerals, secondary_minerals, primary_mineral_groups, secondary_mineral_groups = mineral_groups()
# --> 131 pf_data = syntheric_vars(primary_mineral_groups, secondary_mineral_groups, data)
#     133 print(f'Primary minerals: {primary_minerals}')
#     134 print(f'Secondary minerals: {secondary_minerals}')
#
# File ~/work/hydrothermal_alteration/paper_figures/pf_data.py:19, in syntheric_vars(primary_mineral_groups, secondary_mineral_groups, data)
#      17 for group, minerals in primary_mineral_groups.items():
#      18     minerals = [string + "_VF" for string in minerals]
# ...

# %%
# Parameters
basecase = 4
time = 1000

# %%
subset = data.sel(x=slice(300,1500), time=time).isel(z=-1).squeeze()
display(subset['Liquid Z-Velocity'])
region_cells = len(subset['Liquid Z-Velocity'])

cell_area = 46.875 * 100 # m^2
m3_to_kg = 1000 # kg / m^3

vol_flux = subset['Liquid Z-Velocity']
vol_flux = vol_flux / (365 *24 * 3600) # m^3 / s 
vol_flux = vol_flux * m3_to_kg # kg / s
print(vol_flux.std().values)
print(vol_flux.mean().values)
print(vol_flux.min())
# Out:
# <xarray.DataArray 'Liquid Z-Velocity' (x: 26)>
# array([-0.18765905, -0.30215486, -0.33409316, -0.32732278, -0.30625202,
#        -0.28079705, -0.2551    , -0.23089489, -0.20885877, -0.18918266,
#        -0.17182843, -0.15665169, -0.14346373, -0.13206364, -0.12225519,
#        -0.11385548, -0.10669894, -0.1006388 , -0.09554715, -0.09131421,
#        -0.08784727, -0.08506953, -0.08291891, -0.08134707, -0.08031853,
#        -0.07981001])
# Coordinates:
#     time     float64 1e+03
#   * x        (x) float64 304.7 351.6 398.4 ... 1.383e+03 1.43e+03 1.477e+03
#     y        float64 50.0
#     z        float64 1.477e+03
# Attributes:
#     units:    m_per_y
# 2.6881180774143312e-06
# -5.3101020267416e-06
# <xarray.DataArray 'Liquid Z-Velocity' ()>
# array(-1.05940246e-05)
# Coordinates:
#     time     float64 1e+03
#     y        float64 50.0
#     z        float64 1.477e+03

# %%
subset = data.sel(x=0, method='nearest'), time=time).isel(z=-1).squeeze()
display(subset['Liquid Z-Velocity'])
region_cells = len(subset['Liquid Z-Velocity'])

cell_area = 46.875 * 100 # m^2
m3_to_kg = 1000 # kg / m^3

vol_flux = subset['Liquid Z-Velocity']
vol_flux = vol_flux / (365 *24 * 3600) # m^3 / s 
vol_flux = vol_flux * m3_to_kg # kg / s
print(vol_flux.std().values)
print(vol_flux.mean().values)
print(vol_flux.min())
# Out:
# <xarray.DataArray 'Liquid Z-Velocity' (x: 26)>
# array([-0.18765905, -0.30215486, -0.33409316, -0.32732278, -0.30625202,
#        -0.28079705, -0.2551    , -0.23089489, -0.20885877, -0.18918266,
#        -0.17182843, -0.15665169, -0.14346373, -0.13206364, -0.12225519,
#        -0.11385548, -0.10669894, -0.1006388 , -0.09554715, -0.09131421,
#        -0.08784727, -0.08506953, -0.08291891, -0.08134707, -0.08031853,
#        -0.07981001])
# Coordinates:
#     time     float64 1e+03
#   * x        (x) float64 304.7 351.6 398.4 ... 1.383e+03 1.43e+03 1.477e+03
#     y        float64 50.0
#     z        float64 1.477e+03
# Attributes:
#     units:    m_per_y
# 2.6881180774143312e-06
# -5.3101020267416e-06
# <xarray.DataArray 'Liquid Z-Velocity' ()>
# array(-1.05940246e-05)
# Coordinates:
#     time     float64 1e+03
#     y        float64 50.0
#     z        float64 1.477e+03
