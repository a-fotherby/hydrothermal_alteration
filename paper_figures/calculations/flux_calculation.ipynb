# %%
# %load_ext autoreload
# %autoreload 2
import cmcrameri.cm as cm  # Importing the cmcrameri colormaps
# %run '../pf_data.py' '~/work/hydrothermal_alteration/pflotran_model/flow_steady_state/steady_flow.h5'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Error: The following variables are not in the xarray object: ['Forsterite_VF', 'Fayalite_VF']. Mineral not found.
# Assuming flow only simulation, data available.

# %%
# Parameters
basecase = 4
time = 1000

# %%
pf_data['Liquid Z-Velocity']
# Out:
# <xarray.DataArray 'Liquid Z-Velocity' (time: 41, x: 32, y: 1, z: 32)> Size: 336kB
# array([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#
# ...
#
#        [[[ 4.32751685e-02,  1.26733249e-01,  2.04845175e-01, ...,
# ...

# %%
subset = pf_data.sel(z=1500, time=time, method='nearest').squeeze()
condition = pf_data['Liquid Z-Velocity'].sel(z=1500, time=time, method='nearest') < 0
downwelling = pf_data['Liquid Z-Velocity'].sel(z=1500, time=time, method='nearest').where(condition) # m/yr

cell_area = 46.875 * 100 # m^2
s_per_yr = 365 * 24 * 3600 # s / yr
m3_to_kg = 1000 # kg / m^3

vol_flux = downwelling * cell_area # m^3 / yr

vol_flux = vol_flux / s_per_yr # m^3 / s 
mass_flux = vol_flux * m3_to_kg # kg / s
print(vol_flux.std().values)
print(vol_flux.mean().values)
print(vol_flux.min())
# Out:
# 1.1098961433332267e-05
# -5.6191949538229306e-05
# <xarray.DataArray 'Liquid Z-Velocity' ()> Size: 8B
# array(-6.46220954e-05)
# Coordinates:
#     time     float64 8B 1e+03
#     z        float64 8B 1.477e+03
