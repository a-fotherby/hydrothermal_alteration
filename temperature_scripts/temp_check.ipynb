# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temps = pd.read_csv('temp_test/2_A.txt')

gradient = temps.diff()

for row in temps.iterrows():
    plt.scatter(row[0]*20, row[-1])

# %%
gradient.plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame.diff??

# %%
gradient
# Out:
#      2.0
# 0    NaN
# 1    1.8
# 2    1.8
# 3    1.8
# 4    1.8
# ..   ...
# 169  1.8
# 170  1.8
# 171  1.8
# 172  1.8
# 173  1.8
#
# [174 rows x 1 columns]
