# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
temps = pd.read_csv('on_axis_temp.txt')

gradient = temps.diff()

for row in temps.iterrows():
    plt.scatter(row[0]*20, row[-1])

# %%
gradient.plot()
# Out:
# <AxesSubplot:>
